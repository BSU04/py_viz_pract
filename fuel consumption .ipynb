# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("fuel consumption.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22556 entries, 0 to 22555
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   YEAR              22556 non-null  int64
#  1   MAKE              22556 non-null  object
#  2   MODEL             22556 non-null  object
#  3   VEHICLE CLASS     22556 non-null  object
#  4   ENGINE SIZE       22556 non-null  float64
#  5   CYLINDERS         22556 non-null  int64
#  6   TRANSMISSION      22556 non-null  object
#  7   FUEL              22556 non-null  object
#  8   FUEL CONSUMPTION  22556 non-null  float64
#  9   HWY (L/100 km)    22556 non-null  float64
#  10  COMB (L/100 km)   22556 non-null  float64
#  11  COMB (mpg)        22556 non-null  int64
#  12  EMISSIONS         22556 non-null  int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# Model
#
#     4WD/4X4 = Four-wheel drive
#     AWD = All-wheel drive
#     CNG = Compressed natural gas
#     FFV = Flexible-fuel vehicle
#     NGV = Natural gas vehicle
#     # = High output engine that provides more power than the standard engine of the same size
#
# Transmission
#
#     A = Automatic
#     AM = Automated manual
#     AS = Automatic with select shift
#     AV = Continuously variable
#     M = Manual
#     3 - 10 = Number of gears
#     Fuel Type
#     X = Regular gasoline
#     Z = Premium gasoline
#     D = Diesel
#     E = Ethanol (E85)
#     N = Natural Gas
#
# Fuel Consumption
# City and highway fuel consumption ratings are shown in litres per 100 kilometres (L/100 km) - combined rating (55% city, 45% hwy) is shown in L/100 km and in miles per imperial gallon (mpg)
# CO2 Emissions (g/km),Estimated tailpipe carbon dioxide emissions (in grams per kilometre) are based on fuel type and the combined fuel consumption rating.

# %%
df.head(5)
# Out:
#    YEAR   MAKE    MODEL VEHICLE CLASS  ENGINE SIZE  CYLINDERS TRANSMISSION  \
# 0  2000  ACURA    1.6EL       COMPACT          1.6          4           A4
# 1  2000  ACURA    1.6EL       COMPACT          1.6          4           M5
# 2  2000  ACURA    3.2TL      MID-SIZE          3.2          6          AS5
# 3  2000  ACURA    3.5RL      MID-SIZE          3.5          6           A4
# 4  2000  ACURA  INTEGRA    SUBCOMPACT          1.8          4           A4
#
#   FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  COMB (mpg)  \
# 0    X               9.2             6.7              8.1          35
# 1    X               8.5             6.5              7.6          37
# 2    Z              12.2             7.4             10.0          28
# 3    Z              13.4             9.2             11.5          25
# 4    X              10.0             7.0              8.6          33
#
#    EMISSIONS
# 0        186
# 1        175
# 2        230
# 3        264
# 4        198

# %%
df.describe()
# Out:
#                YEAR   ENGINE SIZE     CYLINDERS  FUEL CONSUMPTION  \
# count  22556.000000  22556.000000  22556.000000      22556.000000
# mean    2011.554442      3.356646      5.854141         12.763513
# std        6.298269      1.335425      1.819597          3.500999
# min     2000.000000      0.800000      2.000000          3.500000
# 25%     2006.000000      2.300000      4.000000         10.400000
# 50%     2012.000000      3.000000      6.000000         12.300000
# 75%     2017.000000      4.200000      8.000000         14.725000
# max     2022.000000      8.400000     16.000000         30.600000
#
#        HWY (L/100 km)  COMB (L/100 km)    COMB (mpg)     EMISSIONS
# count    22556.000000     22556.000000  22556.000000  22556.000000
# mean         8.919126        11.034341     27.374534    250.068452
# std          2.274764         2.910920      7.376982     59.355276
# min          3.200000         3.600000     11.000000     83.000000
# ...

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# ## Histogram

# %% [markdown]
# ***Histogram contains a group of bars that show the density of the data***

# %%
sns.histplot(x="COMB (mpg)",data=df,color="red",bins=7,kde=True)
plt.xlabel("Combustion");
plt.ylabel("Count")

# kde = The KDE plot is the method used to visualize the distribution of the dataset.
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Bar Chart (Count Plot)

# %% [markdown]
# ***A bar chart is a way of summarizing a set of categorical data***

# %%
df["FUEL"].unique()
# Out:
# array(['X', 'Z', 'E', 'N', 'D'], dtype=object)

# %%
sns.countplot(x="FUEL",data=df);

# %% [markdown]
# ## Pie Chart

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# ## Barplot (Categorical v/s Numerical)

# %%
plt.figure(figsize=(7,5))
sns.barplot(x="FUEL",y="FUEL CONSUMPTION",data=df);
plt.xlabel("Fuel")
plt.ylabel("Fuel Consumption")
plt.title("Fuel Consumption w.r.t fuel types")
# Out:
# Text(0.5, 1.0, 'Fuel Consumption w.r.t fuel types')

# %% [markdown]
# ## Violinplot

# %%
sns.violinplot(x="FUEL",y="FUEL CONSUMPTION",data=df)
# Out:
# <AxesSubplot:xlabel='FUEL', ylabel='FUEL CONSUMPTION'>

# %% [markdown]
# ## Scatterplot (Numerical v/s Numerical)

# %%
sns.scatterplot(x="CYLINDERS",y="EMISSIONS",data=df,alpha=0.7);

# %%
sns.scatterplot(x="HWY (L/100 km)",y="FUEL CONSUMPTION",data=df)
# Out:
# <AxesSubplot:xlabel='HWY (L/100 km)', ylabel='FUEL CONSUMPTION'>

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %%
plt.figure(figsize=(8,5.5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x="EMISSIONS",data=df,color="red")
# Out:
# <AxesSubplot:xlabel='EMISSIONS'>
