# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
iris = sns.load_dataset("iris")

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris["sepal_length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
iris["sepal_length"].head(10)
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# 5    5.4
# 6    4.6
# 7    5.0
# 8    4.4
# 9    4.9
# Name: sepal_length, dtype: float64

# %%
iris["sepal_length"].sort_values(ascending=False).head(10)
# Out:
# 131    7.9
# 135    7.7
# 122    7.7
# 117    7.7
# 118    7.7
# 105    7.6
# 130    7.4
# 107    7.3
# 125    7.2
# 109    7.2
# Name: sepal_length, dtype: float64

# %%
plt.figure(figsize=(7,6))
sns.heatmap(iris.corr(),annot=True,data=iris)
# Out:
# <AxesSubplot:>

# %%
iris.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x="sepal_length",data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length'>
