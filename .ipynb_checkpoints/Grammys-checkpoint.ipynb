# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
grammys = pd.read_csv("../Datasets/grammys.csv")

# %%
sns.countplot(x="Racial/Ethnic group",data=grammys)
# Out:
# <AxesSubplot:xlabel='Racial/Ethnic group', ylabel='count'>

# %%
sns.histplot(x="Racial/Ethnic group",data=grammys)
# Out:
# <AxesSubplot:xlabel='Racial/Ethnic group', ylabel='Count'>

# %%
grammys.head(10)
# Out:
#    Rolling Stone Magazine Rank              Artist Racial/Ethnic group  \
# 0                            1         The Beatles      White/European
# 1                            2           Bob Dylan      White/European
# 2                            3       Elvis Presley      White/European
# 3                            4  The Rolling Stones      White/European
# 4                            5         Chuck Berry       Black/African
# 5                            6        Jimi Hendrix       Black/African
# 6                            7         James Brown       Black/African
# 7                            8      Little Richard       Black/African
# 8                            9     Aretha Franklin       Black/African
# 9                           10         Ray Charles       Black/African
#
#    Main Grammy awards  Main Grammy Nominations  Total Awards  \
# 0                   2                       10            14
# 1                   1                        4            10
# ...

# %%
plt.figure(figsize=(5,3))
sns.barplot(x="Artist",y="Total Awards",data=grammys)
plt.xlabel("Artists Name")
# Out:
# Text(0.5, 0, 'Artists Name')

# %%
grammys.shape
# Out:
# (100, 8)

# %%
x = grammys.head(10).copy()

# %%
x
# Out:
#    Rolling Stone Magazine Rank              Artist Racial/Ethnic group  \
# 0                            1         The Beatles      White/European
# 1                            2           Bob Dylan      White/European
# 2                            3       Elvis Presley      White/European
# 3                            4  The Rolling Stones      White/European
# 4                            5         Chuck Berry       Black/African
# 5                            6        Jimi Hendrix       Black/African
# 6                            7         James Brown       Black/African
# 7                            8      Little Richard       Black/African
# 8                            9     Aretha Franklin       Black/African
# 9                           10         Ray Charles       Black/African
#
#    Main Grammy awards  Main Grammy Nominations  Total Awards  \
# 0                   2                       10            14
# 1                   1                        4            10
# ...

# %%
plt.figure(figsize=(16,6))
sns.barplot(x="Artist",y="Total Awards",data=x);

# %%
grammys.head(10)
# Out:
#    Rolling Stone Magazine Rank              Artist Racial/Ethnic group  \
# 0                            1         The Beatles      White/European
# 1                            2           Bob Dylan      White/European
# 2                            3       Elvis Presley      White/European
# 3                            4  The Rolling Stones      White/European
# 4                            5         Chuck Berry       Black/African
# 5                            6        Jimi Hendrix       Black/African
# 6                            7         James Brown       Black/African
# 7                            8      Little Richard       Black/African
# 8                            9     Aretha Franklin       Black/African
# 9                           10         Ray Charles       Black/African
#
#    Main Grammy awards  Main Grammy Nominations  Total Awards  \
# 0                   2                       10            14
# 1                   1                        4            10
# ...

# %%
sns.scatterplot(x="Total Nominations",y="Total Awards",data=grammys);
